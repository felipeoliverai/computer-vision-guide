# %% [markdown]
# #### Utils frameworks tutorial
#
# <br>

# %%
import os 
import glob

# %%
# list directory 
path = os.listdir("drive/MyDrive")
path
# Out:
# ['Currículo ',
#  'Banco de dados- Estudo ',
#  'FIAP ',
#  'Livros',
#  'Machine Learning ',
#  'Deep Learning - Projetos',
#  'Machine Learning - Notebooks',
#  'Curriculo_felipe.docx',
#  'inglês',
#  'CNN-Arquitetura.drawio']

# %%
# hadling files (testing) 

file_list = []
paths = "drive/MyDrive"

for path in paths:
  if path.endswith(".docx"):
    file_list.append(path)

# %%
# glob 

glob.glob("drive/MyDrive/*docx")
# Out:
# ['drive/MyDrive/Curriculo_felipe.docx']

# %%
# glob hadling files

images_path = "/content/drive/MyDrive/Deep Learning - Projetos/GANs/imagens"
img_list = []

for image in glob.glob("/content/drive/MyDrive/Deep Learning - Projetos/GANs/imagens/*.jpg"):
  img_list.append(image)


len(img_list)
# Out:
# 2334

# %%
# images file
img_list[0]
# Out:
# '/content/drive/MyDrive/Deep Learning - Projetos/GANs/imagens/8009.jpg'

# %%
# glob enable load images

from tensorflow.keras.preprocessing.image import array_to_img, load_img
import cv2 
import matplotlib.pyplot as plt 

img = load_img(img_list[30])


plt.figure(figsize=(10,5))
plt.imshow(img)

# %%
print(os.getcwd())
# Out:
# /content

# %%
# change directory 
os.chdir('/content/drive/MyDrive/Deep Learning - Projetos')

# %%
# new directory 
os.listdir()
# Out:
# ['Introdução TensorFlow ',
#  'NLP',
#  'Covid-19 x-ray ',
#  'Classificação de Texto - Twitter ',
#  'NLP - Apple Sentiments',
#  'Embeddings ',
#  'Transfer-learning',
#  'computer-vision-guide',
#  'Intel Images',
#  'TensorFlow 2.0 - Udemy ',
#  'GANs',
#  'YOLOv4',
#  'Bibliotecas',
#  'new-dir']

# %%
# currently directory 
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Deep Learning - Projetos

# %%
# create directory 

os.makedirs("OS-testing")
os.listdir()
# Out:
# ['Introdução TensorFlow ',
#  'NLP',
#  'Covid-19 x-ray ',
#  'Classificação de Texto - Twitter ',
#  'NLP - Apple Sentiments',
#  'Embeddings ',
#  'Transfer-learning',
#  'computer-vision-guide',
#  'Intel Images',
#  'TensorFlow 2.0 - Udemy ',
#  'GANs',
#  'YOLOv4',
#  'Bibliotecas',
#  'new-dir',
#  'OS-testing']

# %%
# remove directory 
os.rmdir("OS-testing")
os.listdir()
# Out:
# ['Introdução TensorFlow ',
#  'NLP',
#  'Covid-19 x-ray ',
#  'Classificação de Texto - Twitter ',
#  'NLP - Apple Sentiments',
#  'Embeddings ',
#  'Transfer-learning',
#  'computer-vision-guide',
#  'Intel Images',
#  'TensorFlow 2.0 - Udemy ',
#  'GANs',
#  'YOLOv4',
#  'Bibliotecas',
#  'new-dir']

# %%
# create not exists dir 

if not os.path.exists("new-dir"):
  os.makedirs("new-dir")

# %%
os.listdir()
# Out:
# ['Introdução TensorFlow ',
#  'NLP',
#  'Covid-19 x-ray ',
#  'Classificação de Texto - Twitter ',
#  'NLP - Apple Sentiments',
#  'Embeddings ',
#  'Transfer-learning',
#  'computer-vision-guide',
#  'Intel Images',
#  'TensorFlow 2.0 - Udemy ',
#  'GANs',
#  'YOLOv4',
#  'Bibliotecas',
#  'new-dir']

# %%
# rename file 
os.chdir('/content/drive/MyDrive/Deep Learning - Projetos/Bibliotecas')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Deep Learning - Projetos/Bibliotecas'

# %%
os.listdir()
# Out:
# ['utils-01.ipynb', 'mountain-snow-01.jpg', 'airplane.png']

# %%
# rename 
os.rename('mountain-snow-01.jpg','mountain-01.jpg')
os.listdir()
# Out:
# ['utils-01.ipynb', 'mountain-01.jpg', 'airplane.png']

# %%
# size of the file 

print(os.stat("mountain-01.jpg").st_size, "bytes")
# Out:
# 188516 bytes

# %%
# show all directory 

for dirpath, dirnames, filenames in os.walk('/content/drive/MyDrive/Deep Learning - Projetos/YOLOv4'):
  print('Current path: {}'.format(dirpath))
  print('Directories: {}'.format(dirnames))
  print('file names: {}'.format(filenames))
  print('\n')
# Out:
# Current path: /content/drive/MyDrive/Deep Learning - Projetos/YOLOv4
# Directories: ['images']
# file names: ['YOLOv4 - Tutorial.ipynb', 'YOLO_v4_Object_Detection_with_Darknet.ipynb']
#
#
# Current path: /content/drive/MyDrive/Deep Learning - Projetos/YOLOv4/images
# Directories: []
# file names: ['mountain-person.jpg', 'airplane.png', 'dog.jpeg']

# %% [markdown]
# <br>
# <hr>
